# %%
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

user_secrets = UserSecretsClient()
secret_value = user_secrets.get_secret('huggingface_token')
login(token=secret_value)

# %%
# !pip install lm-eval datasets torch transformers accelerate tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 2.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 83.3 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 32.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.9 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !git clone https://github.com/akshat652256/ShortGPT.git
# Out:
# Cloning into 'ShortGPT'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 208 (delta 41), reused 41 (delta 32), pack-reused 154 (from 1)
# Receiving objects: 100% (208/208), 109.53 KiB | 5.48 MiB/s, done.
# Resolving deltas: 100% (129/129), done.

# %%
# %cd ShortGPT/short_gpt
# Out:
# /kaggle/working/ShortGPT/short_gpt

# %%
# !python NON-BI_test.py \
    --model_name "google/gemma-2b" \
    --n_prune_layers 0 \
    --eval_tasks crows_pairs_english_gender
# Out:
# Initializing google/gemma-2b...
# tokenizer_config.json: 100%|███████████████| 33.6k/33.6k [00:00<00:00, 33.5MB/s]
# tokenizer.model: 100%|█████████████████████| 4.24M/4.24M [00:00<00:00, 7.01MB/s]
# tokenizer.json: 100%|██████████████████████| 17.5M/17.5M [00:00<00:00, 39.2MB/s]
# ...
# config.json: 100%|█████████████████████████████| 627/627 [00:00<00:00, 4.25MB/s]
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
# !python NON-BI_test.py \
    --model_name "google/gemma-2b" \
    --n_prune_layers 2 \
    --eval_tasks crows_pairs_english_gender
# Out:
# Initializing google/gemma-2b...
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
# !python NON-BI_test.py \
    --model_name "google/gemma-2b" \
    --n_prune_layers 9 \
    --eval_tasks crows_pairs_english_gender

# %%
# !python NON-BI_test.py \
    --model_name "google/gemma-2b" \
    --n_prune_layers 16 \
    --eval_tasks crows_pairs_english_gender

# %%
# %cd ..

# %%
# !rm -rf ShortGPT
